# %%
import sys
sys.path.append("..")
from FusionModel.scripts.ari_group_prior import *

plot_ari(model_type=['03','04'], K=[10,17,20,34,40,68,100], singleTask=True, singleRest=True,
             looTask=False, looCombined=False, allTask=True, all8=True, existing=True, mds=True)

# %%
    plot_ari(model_type=['03','04'], K=[10,17,20,34,40,68,100], singleTask=True, singleRest=True,
             looTask=False, looCombined=False, allTask=True, all8=True, existing=True, mds=False)

# %%
from FusionModel.scripts.modeling_6 import plot_loo_task, plot_loo_rest

# 1. evaluation on Task
fname = f'/Models/Evaluation/eval_all_asym_K-10to100_7taskHcOdd_on_looTask.tsv'
D = pd.read_csv(model_dir + fname, delimiter='\t')
# plot_result_6(D, t_data='HCP')
plot_loo_task(D, t_data=[0,1,2,3,4,5,6], model_type='03')

# %%
plot_loo_task(D, t_data=[0,1,2,3,4,5,6], model_type='04')
